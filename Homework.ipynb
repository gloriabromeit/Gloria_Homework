# %%
# DEAR TA, MY ANSWERS ARE MARKED BY NUMBERS IN THE COMMENTS!

# Three trends:
# 1) Almost 50% of players who purchased games are aged between 20-24
# 2) 84% of players who purchased games are male
# 3) People aged 35-39 bought the most expensive products according to the average price per person



import pandas as pd
# %config IPCompleter.greedy=True

# %%
file_one = "purchase_data.csv"

# %%
df = pd.read_csv(file_one)

# %%
df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
players = df["SN"].nunique()
players
# Out:
# 576

# %%
# ANSWER 1


PA1 = pd.DataFrame({"Total Players :" : [players]})
PA1
# Out:
#    Total Players :
# 0              576

# %%
unique_items = df["Item ID"].nunique()
unique_items
# Out:
# 183

# %%
PA2 = pd.DataFrame({"Total Players :" : [players], "Number of Unique Items :" : [unique_items]})
PA2
# Out:
#    Total Players :  Number of Unique Items :
# 0              576                       183

# %%
average_price = df["Price"].mean()
average_price
# Out:
# 3.050987179487176

# %%
pd.options.display.float_format = '${:,.2f}'.format
PA3 = pd.DataFrame({"Total Players :" : [players],
                           "Number of Unique Items :" : [unique_items], "Average Price :" : [average_price]})
PA3
# Out:
#    Total Players :  Number of Unique Items :  Average Price :
# 0              576                       183            $3.05

# %%
number_purchases = df["Item Name"].count()
number_purchases
# Out:
# 780

# %%
PA4 = pd.DataFrame({"Total Players :" : [players], "Number of Unique Items :" : [unique_items], 
                           "Average Price :" : [average_price], "Number of Purchases :" : [number_purchases]})
PA4
# Out:
#    Total Players :  Number of Unique Items :  Average Price :  \
# 0              576                       183            $3.05
#
#    Number of Purchases :
# 0                    780

# %%
total_rev = df["Price"].sum()
total_rev
# Out:
# 2379.77

# %%
# ANSWER 2


PA5 = pd.DataFrame({ "Number of Unique Items :" : [unique_items], 
                           "Average Price :" : [average_price], "Number of Purchases :" : [number_purchases],
                          "Total Revenue :" : [total_rev]})
PA5
# Out:
#    Number of Unique Items :  Average Price :  Number of Purchases :  \
# 0                       183            $3.05                    780
#
#    Total Revenue :
# 0        $2,379.77

# %%
df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands  $3.53
# 1                          Frenzied Scimitar  $1.56
# 2                               Final Critic  $4.88
# 3                                Blindscythe  $3.27
# 4                                       Fury  $1.44

# %%
df2 = df.drop_duplicates(["SN"])
df2.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands  $3.53
# 1                          Frenzied Scimitar  $1.56
# 2                               Final Critic  $4.88
# 3                                Blindscythe  $3.27
# 4                                       Fury  $1.44

# %%
genders = df2["Gender"].value_counts()
genders
# Out:
# Male                     484
# Female                    81
# Other / Non-Disclosed     11
# Name: Gender, dtype: int64

# %%
malecount = genders["Male"]
malecount
# Out:
# 484

# %%
totalcount = genders["Male"] + genders["Female"] + genders["Other / Non-Disclosed"]
totalcount
# Out:
# 576

# %%
maleper = (malecount / totalcount)*100
maleper
# Out:
# 84.02777777777779

# %%
femalecount = genders["Female"]
femalecount
# Out:
# 81

# %%
othercount = genders["Other / Non-Disclosed"]
othercount
# Out:
# 11

# %%
femaleper = (femalecount / totalcount)*100
femaleper
# Out:
# 14.0625

# %%
otherper = (othercount / totalcount)*100
otherper
# Out:
# 1.9097222222222223

# %%
pd.options.display.float_format = '{:,.2f}'.format
countingpd = pd.DataFrame ({"Total Count" : [malecount, femalecount, othercount], "Percentage of Players" : [maleper, femaleper, otherper]})
countingpd
# Out:
#    Total Count  Percentage of Players
# 0          484                  84.03
# 1           81                  14.06
# 2           11                   1.91

# %%
# ANSWER 3


countingpd.rename(index={0:'Male', 1:'Female', 2:'Other / Non-Disclosed'}, inplace=True)
countingpd
# Out:
#                        Total Count  Percentage of Players
# Male                           484                  84.03
# Female                          81                  14.06
# Other / Non-Disclosed           11                   1.91

# %%
malepcount = df.loc[df["Gender"] == "Male",  "Purchase ID"].count()
malepcount
# Out:
# 652

# %%
malepav = df.loc[df["Gender"] == "Male",  "Price"].mean()
malepav
# Out:
# 3.0178527607361953

# %%
maleppurch = df.loc[df["Gender"] == "Male",  "Price"].sum()
maleppurch
# Out:
# 1967.64

# %%
malepavpp = maleppurch / malecount
malepavpp
# Out:
# 4.065371900826446

# %%
fmalepcount = df.loc[df["Gender"] == "Female",  "Purchase ID"].count()
fmalepcount
# Out:
# 113

# %%
fmalepav = df.loc[df["Gender"] == "Female",  "Price"].mean()
fmalepav
# Out:
# 3.203008849557519

# %%
fmaleppurch = df.loc[df["Gender"] == "Female",  "Price"].sum()
fmaleppurch
# Out:
# 361.94

# %%
fmalepavpp = fmaleppurch / femalecount
fmalepavpp
# Out:
# 4.468395061728395

# %%
otherppurch = df.loc[df["Gender"] == 'Other / Non-Disclosed',  "Price"].sum()
otherppurch
# Out:
# 50.19

# %%
otherpav = df.loc[df["Gender"] == 'Other / Non-Disclosed',  "Price"].mean()
otherpav
# Out:
# 3.3460000000000005

# %%
otherpcount = df.loc[df["Gender"] == 'Other / Non-Disclosed',  "Purchase ID"].count()
otherpcount
# Out:
# 15

# %%
otherpavpp = otherppurch / othercount
otherpavpp
# Out:
# 4.5627272727272725

# %%
# ANSWER 4

pd.options.display.float_format = '${:,.2f}'.format
purchana = pd.DataFrame ({"Purchase Count" : [fmalepcount, malepcount, otherpcount], "Average Purchase Price" : [fmalepav,malepav, otherpav],"Total Purchase Value" : [fmaleppurch, maleppurch, otherppurch], "Avg Total Purchase per Person" : [fmalepavpp, malepavpp, otherpavpp]})
purchana
purchana.rename(index={0:'Male', 1:'Female', 2:'Other / Non-Disclosed'}, inplace=True)
purchana
# Out:
#                        Purchase Count  Average Purchase Price  \
# Male                              113                   $3.20
# Female                            652                   $3.02
# Other / Non-Disclosed              15                   $3.35
#
#                        Total Purchase Value  Avg Total Purchase per Person
# Male                                $361.94                          $4.47
# Female                            $1,967.64                          $4.07
# Other / Non-Disclosed                $50.19                          $4.56

# %%
df2.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands  $3.53
# 1                          Frenzied Scimitar  $1.56
# 2                               Final Critic  $4.88
# 3                                Blindscythe  $3.27
# 4                                       Fury  $1.44

# %%
bins = [0, 9, 14, 19, 24, 29,34,39,45]
# # Create labels for these bins
labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]
df2["Bins"] = pd.cut(df["Age"], bins, labels=labels)
df2
# Out:
# C:\Users\Dad\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#      Purchase ID              SN  Age                 Gender  Item ID  \
# 0              0         Lisim78   20                   Male      108
# 1              1     Lisovynya38   40                   Male      143
# 2              2      Ithergue48   24                   Male       92
# 3              3   Chamassasya86   24                   Male      100
# 4              4       Iskosia90   23                   Male      131
# 5              5         Yalae81   22                   Male       81
# 6              6       Itheria73   36                   Male      169
# ...

# %%
# Find how many rows fall into each bin
df3 = df2["Bins"].count()
df3
# Out:
# 576

# %%
# ANSWER 5

df3 = df2.groupby("Bins")
df3.head()
price_mean = df3["Price"].mean()

count1 = df3["Item ID"].count()
countp = df3["Item ID"].count() / 576 *100

pd.options.display.float_format = '{:,.2f}'.format
dataframe3 = pd.DataFrame({"Purchase Count" : count1, "Percentage of Players" : countp})
dataframe3
# Out:
#        Purchase Count  Percentage of Players
# Bins
# <10                17                   2.95
# 10-14              22                   3.82
# 15-19             107                  18.58
# 20-24             258                  44.79
# 25-29              77                  13.37
# 30-34              52                   9.03
# 35-39              31                   5.38
# 40+                12                   2.08

# %%
bins = [0, 9, 14, 19, 24, 29,34,39,45]
# # Create labels for these bins
labels = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]
df["Bins"] = pd.cut(df["Age"], bins, labels=labels)
df
# Out:
#      Purchase ID               SN  Age                 Gender  Item ID  \
# 0              0          Lisim78   20                   Male      108
# 1              1      Lisovynya38   40                   Male      143
# 2              2       Ithergue48   24                   Male       92
# 3              3    Chamassasya86   24                   Male      100
# 4              4        Iskosia90   23                   Male      131
# 5              5          Yalae81   22                   Male       81
# 6              6        Itheria73   36                   Male      169
# 7              7      Iskjaskst81   20                   Male      162
# 8              8        Undjask33   22                   Male       21
# 9              9      Chanosian48   35  Other / Non-Disclosed      136
# 10            10        Inguron55   23                   Male       95
# 11            11     Haisrisuir60   23                   Male      162
# ...

# %%
# ANSWER 6

df4 = df.groupby("Bins")
df4.head()
price_mean2 = df4["Price"].mean()
count2 = df4["SN"].count()
purchval = df4["Price"].sum()
purchvalpp = purchval / count1

pd.options.display.float_format = '${:,.2f}'.format
dataframe4 = pd.DataFrame({"Purchase Count" : count2, "Total Purchase Value" : purchval, "Average Purchase Price" : price_mean2, "Average Purchase Price per Person" : purchvalpp})
dataframe4
# Out:
#        Purchase Count  Total Purchase Value  Average Purchase Price  \
# Bins
# <10                23                $77.13                   $3.35
# 10-14              28                $82.78                   $2.96
# 15-19             136               $412.89                   $3.04
# 20-24             365             $1,114.06                   $3.05
# 25-29             101               $293.00                   $2.90
# 30-34              73               $214.00                   $2.93
# 35-39              41               $147.67                   $3.60
# 40+                13                $38.24                   $2.94
#
#        Average Purchase Price per Person
# Bins
# <10                                $4.54
# 10-14                              $3.76
# 15-19                              $3.86
# 20-24                              $4.32
# 25-29                              $3.81
# 30-34                              $4.12
# 35-39                              $4.76
# ...

# %%
reduced_df2 = df[["SN", "Item ID", "Price"]]
reduced_df2.head()
grouped_df2 = reduced_df2.groupby(["SN"])
grouped_df2.head()
# Out:
#                   SN  Item ID  Price
# 0            Lisim78      108  $3.53
# 1        Lisovynya38      143  $1.56
# 2         Ithergue48       92  $4.88
# 3      Chamassasya86      100  $3.27
# 4          Iskosia90      131  $1.44
# 5            Yalae81       81  $3.61
# 6          Itheria73      169  $2.18
# 7        Iskjaskst81      162  $2.67
# 8          Undjask33       21  $1.10
# 9        Chanosian48      136  $3.58
# 10         Inguron55       95  $4.74
# 11      Haisrisuir60      162  $2.67
# 12      Saelaephos52      116  $4.18
# 13       Assjaskan73        4  $1.70
# 14       Saesrideu94      165  $4.86
# 15         Lisassa64       98  $2.89
# 16         Lisirra25       40  $2.52
# 17         Zontibe81      161  $1.76
# 18         Reunasu60       82  $4.90
# 19         Chamalo71       89  $4.64
# 20      Iathenudil29       57  $4.60
# 21     Phiarithdeu40      168  $1.48
# 22      Siarithria38       24  $3.81
# 23          Eyrian71      151  $3.40
# ...

# %%
price_mean = grouped_df2["Price"].mean()
price_sum = grouped_df2["Price"].sum()
count3 = grouped_df2["Item ID"].count()


dataframe2 = pd.DataFrame({"Item Price" : price_mean, "Purchase Count" : count3, "Total Purchase Value" : price_sum})
dataframe2.head()
# Out:
#               Item Price  Purchase Count  Total Purchase Value
# SN
# Adairialis76       $2.28               1                 $2.28
# Adastirin33        $4.48               1                 $4.48
# Aeda94             $4.91               1                 $4.91
# Aela59             $4.32               1                 $4.32
# Aelaria33          $1.79               1                 $1.79

# %%
# ANSWER 7

result2 = dataframe2.sort_values(["Total Purchase Value"], ascending=False)
result2.head()
# Out:
#              Item Price  Purchase Count  Total Purchase Value
# SN
# Lisosia93         $3.79               5                $18.96
# Idastidru52       $3.86               4                $15.45
# Chamjask73        $4.61               3                $13.83
# Iral74            $3.40               4                $13.62
# Iskadarya95       $4.37               3                $13.10

# %%
reduced_df = df[["Item ID", "Item Name", "Price"]]
reduced_df.head()
# Out:
#    Item ID                                  Item Name  Price
# 0      108  Extraction, Quickblade Of Trembling Hands  $3.53
# 1      143                          Frenzied Scimitar  $1.56
# 2       92                               Final Critic  $4.88
# 3      100                                Blindscythe  $3.27
# 4      131                                       Fury  $1.44

# %%
grouped_df = reduced_df.groupby(["Item ID", "Item Name"])
grouped_df.head()
# Out:
#      Item ID                                     Item Name  Price
# 0        108     Extraction, Quickblade Of Trembling Hands  $3.53
# 1        143                             Frenzied Scimitar  $1.56
# 2         92                                  Final Critic  $4.88
# 3        100                                   Blindscythe  $3.27
# 4        131                                          Fury  $1.44
# 5         81                                     Dreamkiss  $3.61
# 6        169        Interrogator, Blood Blade of the Queen  $2.18
# 7        162                                 Abyssal Shard  $2.67
# 8         21                                     Souleater  $1.10
# 9        136                  Ghastly Adamantite Protector  $3.58
# 10        95                         Singed Onyx Warscythe  $4.74
# 11       162                                 Abyssal Shard  $2.67
# 12       116                       Renewed Skeletal Katana  $4.18
# ...

# %%
price_mean = grouped_df["Price"].mean()
price_sum = grouped_df["Price"].sum()
count4 = grouped_df["Item ID"].count()


dataframe = pd.DataFrame({"Item Price" : price_mean, "Purchase Count" : count4, "Total Purchase Value" : price_sum})
dataframe.head()
# Out:
#                             Item Price  Purchase Count  Total Purchase Value
# Item ID Item Name
# 0       Splinter                 $1.28               4                 $5.12
# 1       Crucifer                 $3.26               3                 $9.78
# 2       Verdict                  $2.48               6                $14.88
# 3       Phantomlight             $2.49               6                $14.94
# 4       Bloodlord's Fetish       $1.70               5                 $8.50

# %%
# ANSWER 8

result = dataframe.sort_values(["Purchase Count"], ascending=False)
result.head()
# Out:
#                                                       Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm       $4.23
# 145     Fiery Glass Crusader                               $4.58
# 108     Extraction, Quickblade Of Trembling Hands          $3.53
# 82      Nirvana                                            $4.90
# 19      Pursuit, Cudgel of Necromancy                      $1.02
#
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 19      Pursuit, Cudgel of Necromancy                              8
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...

# %%
# ANSWER 9

result = dataframe.sort_values(["Total Purchase Value"], ascending=False)
result.head()
# Out:
#                                                       Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm       $4.23
# 82      Nirvana                                            $4.90
# 145     Fiery Glass Crusader                               $4.58
# 92      Final Critic                                       $4.88
# 103     Singed Scalpel                                     $4.35
#
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...
