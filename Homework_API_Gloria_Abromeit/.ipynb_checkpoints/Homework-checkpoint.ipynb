# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime

gkey = "AIzaSyC2yEFd78DIK7fZ3lkNTRsnjZml4RGPEwU"
wkey = "45c89b215804cf8cdb8d60a266ddf95b"
from citipy import citipy

# %%
lat_range = (-90, 90)
lng_range = (-180, 180)

lat_lngs = []
cities = []
city_lat = []
city_long = []

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
for lat_long in lat_lngs:
    city = citipy.nearest_city(lat_long[0], lat_long[1]).city_name
    
    if city not in cities:
        cities.append(city)
        city_lat.append(lat_long[0])
        city_long.append(lat_long[1])

        # Print the city count to confirm sufficient count
print("There are:", len(cities), "cities")
print("There are:", len(city_lat), "lats")
print("There are:", len(city_long), "longs")
# Out:
# There are: 613 cities
# There are: 613 lats
# There are: 613 longs

# %%
temp_dict ={
    "City" : cities,
    "Lat" : city_lat,
    "Lng" : city_long,
    "Temp":"",
    "Humidity":"",
    "Cloudiness":"",
    "Wind Speed":"",
    "Country":"",
    "Date":""}

tempDict = pd.DataFrame(temp_dict)
tempDict.head()
# Out:
#         City        Lat        Lng Temp Humidity Cloudiness Wind Speed  \
# 0    machali -34.644817 -69.883354
# 1     padang  -9.490875  87.206593
# 2    markovo  56.781816  40.225382
# 3  busselton -64.050340  86.129991
# 4        gat  23.750677  12.073141
#
#   Country Date
# 0
# 1
# 2
# 3
# 4

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + wkey + "&q="




city_number = 0
noinfo = 0

for index, row in tempDict.iterrows():
    city = row['City']
    
    response = requests.get(url + city).json()
    
    try:
        
        tempDict.loc[index, 'Temp'] = response['main']['temp']
        tempDict.loc[index, 'Humidity'] = response['main']['humidity']
        tempDict.loc[index, 'Cloudiness'] = response['clouds']['all']
        tempDict.loc[index, 'Wind Speed'] = response['wind']['speed']
        tempDict.loc[index, 'City ID'] = response['id']
        tempDict.loc[index, 'Country'] = response['sys']['country']
        tempDict.loc[index, 'Date'] = response["dt"]
        city_number +=1
        print(f"City Number: {city_number} - City Name: {city}")
    except KeyError:
        
        noinfo +=1
        continue

print("---------------------------------")
print(f"There are {city_number} cities that DO have info")
print(f"there are {noinfo} cities that DO NOT have any info")
print("----------------------------------")
# Out:
# City Number: 1 - City Name: padang
# City Number: 2 - City Name: markovo
# City Number: 3 - City Name: busselton
# City Number: 4 - City Name: gat
# City Number: 5 - City Name: albany
# City Number: 6 - City Name: punta arenas
# City Number: 7 - City Name: saint-philippe
# City Number: 8 - City Name: casper
# City Number: 9 - City Name: ushuaia
# City Number: 10 - City Name: metro
# City Number: 11 - City Name: edmundston
# City Number: 12 - City Name: bluff
# City Number: 13 - City Name: vuktyl
# City Number: 14 - City Name: mutis
# City Number: 15 - City Name: airai
# City Number: 16 - City Name: lasa
# City Number: 17 - City Name: tasiilaq
# City Number: 18 - City Name: chitral
# City Number: 19 - City Name: vila franca do campo
# City Number: 20 - City Name: skjervoy
# City Number: 21 - City Name: lagoa
# City Number: 22 - City Name: tecoanapa
# City Number: 23 - City Name: atuona
# City Number: 24 - City Name: tura
# City Number: 25 - City Name: olga
# City Number: 26 - City Name: benghazi
# City Number: 27 - City Name: yulara
# City Number: 28 - City Name: cartagena del chaira
# City Number: 29 - City Name: mar del plata
# City Number: 30 - City Name: sur
# City Number: 31 - City Name: laguna
# City Number: 32 - City Name: isoka
# City Number: 33 - City Name: kaitangata
# City Number: 34 - City Name: goderich
# City Number: 35 - City Name: talara
# City Number: 36 - City Name: nuuk
# City Number: 37 - City Name: vaini
# City Number: 38 - City Name: fairbanks
# City Number: 39 - City Name: nakamura
# City Number: 40 - City Name: qaanaaq
# City Number: 41 - City Name: butaritari
# City Number: 42 - City Name: cayenne
# City Number: 43 - City Name: rikitea
# City Number: 44 - City Name: puerto escondido
# City Number: 45 - City Name: tuktoyaktuk
# City Number: 46 - City Name: cantapoy
# City Number: 47 - City Name: port elizabeth
# City Number: 48 - City Name: gwadar
# City Number: 49 - City Name: cape town
# City Number: 50 - City Name: nador
# City Number: 51 - City Name: yellowknife
# City Number: 52 - City Name: niamey
# City Number: 53 - City Name: kapaa
# City Number: 54 - City Name: boddam
# City Number: 55 - City Name: ajdabiya
# City Number: 56 - City Name: mataura
# City Number: 57 - City Name: asuncion
# City Number: 58 - City Name: inuvik
# City Number: 59 - City Name: hilo
# City Number: 60 - City Name: cabo san lucas
# City Number: 61 - City Name: mahebourg
# City Number: 62 - City Name: zaraza
# City Number: 63 - City Name: tuatapere
# City Number: 64 - City Name: hermanus
# City Number: 65 - City Name: khatanga
# City Number: 66 - City Name: vestmannaeyjar
# City Number: 67 - City Name: pervomayskiy
# City Number: 68 - City Name: cidreira
# City Number: 69 - City Name: smithers
# City Number: 70 - City Name: bredasdorp
# City Number: 71 - City Name: torbay
# City Number: 72 - City Name: chake chake
# City Number: 73 - City Name: cherskiy
# City Number: 74 - City Name: nanortalik
# City Number: 75 - City Name: taoudenni
# City Number: 76 - City Name: oranjemund
# City Number: 77 - City Name: agde
# City Number: 78 - City Name: ugoofaaru
# City Number: 79 - City Name: port alfred
# City Number: 80 - City Name: puerto ayora
# City Number: 81 - City Name: souillac
# City Number: 82 - City Name: college
# City Number: 83 - City Name: srednekolymsk
# City Number: 84 - City Name: jamestown
# City Number: 85 - City Name: riyadh
# City Number: 86 - City Name: manjeshwar
# City Number: 87 - City Name: komsomolskiy
# City Number: 88 - City Name: katsuura
# City Number: 89 - City Name: hernani
# City Number: 90 - City Name: hobart
# City Number: 91 - City Name: san guillermo
# City Number: 92 - City Name: plettenberg bay
# City Number: 93 - City Name: narasannapeta
# City Number: 94 - City Name: walvis bay
# City Number: 95 - City Name: sidney
# City Number: 96 - City Name: hithadhoo
# City Number: 97 - City Name: newport
# City Number: 98 - City Name: hofn
# City Number: 99 - City Name: sabinas
# City Number: 100 - City Name: ancud
# City Number: 101 - City Name: chipata
# City Number: 102 - City Name: sao joao da barra
# City Number: 103 - City Name: barrow
# City Number: 104 - City Name: berlevag
# City Number: 105 - City Name: baragua
# City Number: 106 - City Name: huejuquilla el alto
# City Number: 107 - City Name: litovko
# City Number: 108 - City Name: charters towers
# City Number: 109 - City Name: camocim
# City Number: 110 - City Name: thompson
# City Number: 111 - City Name: harper
# City Number: 112 - City Name: east london
# City Number: 113 - City Name: luwuk
# City Number: 114 - City Name: zhigansk
# City Number: 115 - City Name: deputatskiy
# City Number: 116 - City Name: san patricio
# City Number: 117 - City Name: preobrazheniye
# City Number: 118 - City Name: roebourne
# City Number: 119 - City Name: new norfolk
# City Number: 120 - City Name: nikolskoye
# City Number: 121 - City Name: the valley
# City Number: 122 - City Name: lebu
# City Number: 123 - City Name: palimbang
# City Number: 124 - City Name: severo-kurilsk
# City Number: 125 - City Name: lossiemouth
# City Number: 126 - City Name: ponta do sol
# City Number: 127 - City Name: te anau
# City Number: 128 - City Name: farafangana
# City Number: 129 - City Name: gazli
# City Number: 130 - City Name: la seyne-sur-mer
# City Number: 131 - City Name: sabang
# City Number: 132 - City Name: glenwood springs
# City Number: 133 - City Name: matara
# City Number: 134 - City Name: isangel
# City Number: 135 - City Name: buka
# City Number: 136 - City Name: sangar
# City Number: 137 - City Name: guerrero negro
# City Number: 138 - City Name: chase
# City Number: 139 - City Name: yar-sale
# City Number: 140 - City Name: esperance
# City Number: 141 - City Name: avera
# City Number: 142 - City Name: bud
# City Number: 143 - City Name: neyshabur
# City Number: 144 - City Name: clyde river
# City Number: 145 - City Name: medicine hat
# City Number: 146 - City Name: effium
# City Number: 147 - City Name: saldanha
# City Number: 148 - City Name: kruisfontein
# City Number: 149 - City Name: cheltenham
# City Number: 150 - City Name: kahului
# City Number: 151 - City Name: otavi
# City Number: 152 - City Name: scottsbluff
# City Number: 153 - City Name: norman wells
# City Number: 154 - City Name: luderitz
# City Number: 155 - City Name: gupitan
# City Number: 156 - City Name: saskylakh
# City Number: 157 - City Name: fare
# City Number: 158 - City Name: aksu
# City Number: 159 - City Name: sharan
# City Number: 160 - City Name: shirokiy
# City Number: 161 - City Name: hasaki
# City Number: 162 - City Name: bambari
# City Number: 163 - City Name: quatre cocos
# City Number: 164 - City Name: port hedland
# City Number: 165 - City Name: ribeira grande
# City Number: 166 - City Name: prince rupert
# City Number: 167 - City Name: den helder
# City Number: 168 - City Name: seidu
# City Number: 169 - City Name: akdepe
# City Number: 170 - City Name: nabire
# City Number: 171 - City Name: castro
# City Number: 172 - City Name: sitka
# City Number: 173 - City Name: havoysund
# City Number: 174 - City Name: sao filipe
# City Number: 175 - City Name: dingle
# City Number: 176 - City Name: abramovka
# City Number: 177 - City Name: pevek
# City Number: 178 - City Name: georgetown
# City Number: 179 - City Name: alice springs
# City Number: 180 - City Name: gisborne
# City Number: 181 - City Name: san cristobal
# City Number: 182 - City Name: rivadavia
# City Number: 183 - City Name: grand gaube
# City Number: 184 - City Name: marawi
# City Number: 185 - City Name: avarua
# City Number: 186 - City Name: tutoia
# City Number: 187 - City Name: vostok
# City Number: 188 - City Name: praya
# City Number: 189 - City Name: hobyo
# City Number: 190 - City Name: ardabil
# City Number: 191 - City Name: kurumkan
# City Number: 192 - City Name: fort frances
# City Number: 193 - City Name: vardo
# City Number: 194 - City Name: northam
# City Number: 195 - City Name: banjar
# City Number: 196 - City Name: ornskoldsvik
# City Number: 197 - City Name: kamaishi
# City Number: 198 - City Name: saint-augustin
# City Number: 199 - City Name: bontang
# City Number: 200 - City Name: burla
# City Number: 201 - City Name: lompoc
# City Number: 202 - City Name: port lincoln
# City Number: 203 - City Name: ahipara
# City Number: 204 - City Name: satuk
# City Number: 205 - City Name: eureka
# City Number: 206 - City Name: rio do sul
# City Number: 207 - City Name: ploufragan
# City Number: 208 - City Name: maldonado
# City Number: 209 - City Name: kirakira
# City Number: 210 - City Name: bonavista
# City Number: 211 - City Name: saurimo
# City Number: 212 - City Name: robertsport
# City Number: 213 - City Name: upington
# City Number: 214 - City Name: launceston
# City Number: 215 - City Name: fort nelson
# City Number: 216 - City Name: moose factory
# City Number: 217 - City Name: carballo
# City Number: 218 - City Name: klaksvik
# City Number: 219 - City Name: shache
# City Number: 220 - City Name: kodiak
# City Number: 221 - City Name: lorengau
# City Number: 222 - City Name: namikupa
# City Number: 223 - City Name: tucumcari
# City Number: 224 - City Name: iqaluit
# City Number: 225 - City Name: jacareacanga
# City Number: 226 - City Name: wadi musa
# City Number: 227 - City Name: verkhnevilyuysk
# City Number: 228 - City Name: peace river
# City Number: 229 - City Name: codajas
# City Number: 230 - City Name: tigre
# City Number: 231 - City Name: dikson
# City Number: 232 - City Name: kununurra
# City Number: 233 - City Name: temuco
# City Number: 234 - City Name: yola
# City Number: 235 - City Name: san luis
# City Number: 236 - City Name: ouahigouya
# City Number: 237 - City Name: poyarkovo
# City Number: 238 - City Name: mount gambier
# City Number: 239 - City Name: upernavik
# City Number: 240 - City Name: talas
# City Number: 241 - City Name: shimoni
# City Number: 242 - City Name: kijang
# City Number: 243 - City Name: markova
# City Number: 244 - City Name: cacequi
# City Number: 245 - City Name: boende
# City Number: 246 - City Name: ariquemes
# City Number: 247 - City Name: victoria
# City Number: 248 - City Name: moranbah
# City Number: 249 - City Name: chato
# City Number: 250 - City Name: azanka
# City Number: 251 - City Name: arraial do cabo
# City Number: 252 - City Name: kathu
# City Number: 253 - City Name: codrington
# City Number: 254 - City Name: hatillo
# City Number: 255 - City Name: novikovo
# City Number: 256 - City Name: shahr-e babak
# City Number: 257 - City Name: pisco
# City Number: 258 - City Name: vanavara
# City Number: 259 - City Name: basoko
# City Number: 260 - City Name: jiquipilas
# City Number: 261 - City Name: bilma
# City Number: 262 - City Name: yueyang
# City Number: 263 - City Name: ucluelet
# City Number: 264 - City Name: gilgit
# City Number: 265 - City Name: zhifang
# City Number: 266 - City Name: nishihara
# City Number: 267 - City Name: namibe
# City Number: 268 - City Name: tiksi
# City Number: 269 - City Name: portland
# City Number: 270 - City Name: ostrovnoy
# City Number: 271 - City Name: ribnica
# City Number: 272 - City Name: soeng sang
# City Number: 273 - City Name: namatanai
# City Number: 274 - City Name: aboisso
# City Number: 275 - City Name: narsaq
# City Number: 276 - City Name: klerksdorp
# City Number: 277 - City Name: ghanzi
# City Number: 278 - City Name: ostrovskoye
# City Number: 279 - City Name: santiago
# City Number: 280 - City Name: shitkino
# City Number: 281 - City Name: ixtapa
# City Number: 282 - City Name: hope
# City Number: 283 - City Name: alekseyevsk
# City Number: 284 - City Name: deer lake
# City Number: 285 - City Name: saint george
# City Number: 286 - City Name: incourt
# City Number: 287 - City Name: carnarvon
# City Number: 288 - City Name: blackpool
# City Number: 289 - City Name: poum
# City Number: 290 - City Name: kutum
# City Number: 291 - City Name: provideniya
# City Number: 292 - City Name: buraydah
# City Number: 293 - City Name: leningradskiy
# City Number: 294 - City Name: ocean city
# City Number: 295 - City Name: atambua
# City Number: 296 - City Name: petropavlovsk-kamchatskiy
# City Number: 297 - City Name: bethlehem
# City Number: 298 - City Name: saquarema
# City Number: 299 - City Name: bandarbeyla
# City Number: 300 - City Name: ilulissat
# City Number: 301 - City Name: zhanakorgan
# City Number: 302 - City Name: pontes e lacerda
# City Number: 303 - City Name: port macquarie
# City Number: 304 - City Name: igreja nova
# City Number: 305 - City Name: itirapina
# City Number: 306 - City Name: faanui
# City Number: 307 - City Name: coihaique
# City Number: 308 - City Name: lumphat
# City Number: 309 - City Name: dabra
# City Number: 310 - City Name: talnakh
# City Number: 311 - City Name: oksfjord
# City Number: 312 - City Name: placido de castro
# City Number: 313 - City Name: manta
# City Number: 314 - City Name: richards bay
# City Number: 315 - City Name: helong
# City Number: 316 - City Name: kavieng
# City Number: 317 - City Name: muisne
# City Number: 318 - City Name: salinopolis
# City Number: 319 - City Name: san matias
# City Number: 320 - City Name: adrar
# City Number: 321 - City Name: usogorsk
# City Number: 322 - City Name: bethel
# City Number: 323 - City Name: dalnegorsk
# City Number: 324 - City Name: kieta
# City Number: 325 - City Name: henties bay
# City Number: 326 - City Name: ratnagiri
# City Number: 327 - City Name: krasnyy yar
# City Number: 328 - City Name: steamboat springs
# City Number: 329 - City Name: cabedelo
# City Number: 330 - City Name: tautira
# City Number: 331 - City Name: issoire
# City Number: 332 - City Name: xalpatlahuac
# City Number: 333 - City Name: kokuy
# City Number: 334 - City Name: buta
# City Number: 335 - City Name: kangaatsiaq
# City Number: 336 - City Name: aklavik
# City Number: 337 - City Name: venice
# City Number: 338 - City Name: holme
# City Number: 339 - City Name: rapid valley
# City Number: 340 - City Name: lavrentiya
# City Number: 341 - City Name: druzhba
# City Number: 342 - City Name: abalak
# City Number: 343 - City Name: la ronge
# City Number: 344 - City Name: contamana
# City Number: 345 - City Name: hualmay
# City Number: 346 - City Name: awjilah
# City Number: 347 - City Name: yenangyaung
# City Number: 348 - City Name: arman
# City Number: 349 - City Name: kramat
# City Number: 350 - City Name: zernograd
# City Number: 351 - City Name: touros
# City Number: 352 - City Name: kjollefjord
# City Number: 353 - City Name: shenjiamen
# City Number: 354 - City Name: takaungu
# City Number: 355 - City Name: midleton
# City Number: 356 - City Name: half moon bay
# City Number: 357 - City Name: manzanillo
# City Number: 358 - City Name: pulaski
# City Number: 359 - City Name: wanaka
# City Number: 360 - City Name: minab
# City Number: 361 - City Name: nanhyanga
# City Number: 362 - City Name: buluang
# City Number: 363 - City Name: peniche
# City Number: 364 - City Name: tadine
# City Number: 365 - City Name: mutoko
# City Number: 366 - City Name: santa marta
# City Number: 367 - City Name: chuy
# City Number: 368 - City Name: geraldton
# City Number: 369 - City Name: leninogorsk
# City Number: 370 - City Name: evensk
# City Number: 371 - City Name: pedernales
# City Number: 372 - City Name: chicama
# City Number: 373 - City Name: rocha
# City Number: 374 - City Name: labuhan
# City Number: 375 - City Name: broken hill
# City Number: 376 - City Name: tocopilla
# City Number: 377 - City Name: coquimbo
# City Number: 378 - City Name: gasa
# City Number: 379 - City Name: soyo
# City Number: 380 - City Name: kushima
# City Number: 381 - City Name: bosobolo
# City Number: 382 - City Name: chilca
# City Number: 383 - City Name: bathsheba
# City Number: 384 - City Name: kambove
# City Number: 385 - City Name: thinadhoo
# City Number: 386 - City Name: yerbogachen
# City Number: 387 - City Name: kouango
# City Number: 388 - City Name: sinnamary
# City Number: 389 - City Name: dickinson
# City Number: 390 - City Name: uribia
# City Number: 391 - City Name: great yarmouth
# City Number: 392 - City Name: jasper
# City Number: 393 - City Name: bambous virieux
# City Number: 394 - City Name: port-gentil
# City Number: 395 - City Name: thomastown
# City Number: 396 - City Name: mukhen
# City Number: 397 - City Name: ketchikan
# City Number: 398 - City Name: kumluca
# City Number: 399 - City Name: grindavik
# City Number: 400 - City Name: vaitape
# City Number: 401 - City Name: tilichiki
# City Number: 402 - City Name: mantua
# City Number: 403 - City Name: neopolis
# City Number: 404 - City Name: talakan
# City Number: 405 - City Name: flinders
# City Number: 406 - City Name: bintulu
# City Number: 407 - City Name: lokosovo
# City Number: 408 - City Name: merauke
# City Number: 409 - City Name: karratha
# City Number: 410 - City Name: longyearbyen
# City Number: 411 - City Name: kuytun
# City Number: 412 - City Name: candolim
# City Number: 413 - City Name: bosaso
# City Number: 414 - City Name: sunrise manor
# City Number: 415 - City Name: sechura
# City Number: 416 - City Name: along
# City Number: 417 - City Name: visnes
# City Number: 418 - City Name: bethanien
# City Number: 419 - City Name: riacho de santana
# City Number: 420 - City Name: husavik
# City Number: 421 - City Name: minot
# City Number: 422 - City Name: moindou
# City Number: 423 - City Name: west bay
# City Number: 424 - City Name: svolvaer
# City Number: 425 - City Name: katobu
# City Number: 426 - City Name: san pedro de macoris
# City Number: 427 - City Name: bereda
# City Number: 428 - City Name: comodoro rivadavia
# City Number: 429 - City Name: luganville
# City Number: 430 - City Name: hamilton
# City Number: 431 - City Name: chapais
# City Number: 432 - City Name: idaho falls
# City Number: 433 - City Name: talcahuano
# City Number: 434 - City Name: ngorongoro
# City Number: 435 - City Name: constitucion
# City Number: 436 - City Name: pringsewu
# City Number: 437 - City Name: porto velho
# City Number: 438 - City Name: barcelos
# City Number: 439 - City Name: kenai
# City Number: 440 - City Name: sisimiut
# City Number: 441 - City Name: marathon
# City Number: 442 - City Name: cape coast
# City Number: 443 - City Name: nikel
# City Number: 444 - City Name: aswan
# City Number: 445 - City Name: campo maior
# City Number: 446 - City Name: beringovskiy
# City Number: 447 - City Name: dudinka
# City Number: 448 - City Name: toktogul
# City Number: 449 - City Name: lindi
# City Number: 450 - City Name: huambo
# City Number: 451 - City Name: los llanos de aridane
# City Number: 452 - City Name: vila velha
# City Number: 453 - City Name: morag
# City Number: 454 - City Name: khandbari
# City Number: 455 - City Name: shancheng
# City Number: 456 - City Name: kem
# City Number: 457 - City Name: fort-shevchenko
# City Number: 458 - City Name: malm
# City Number: 459 - City Name: castrovillari
# City Number: 460 - City Name: huarmey
# City Number: 461 - City Name: honningsvag
# City Number: 462 - City Name: warrington
# City Number: 463 - City Name: whitehorse
# City Number: 464 - City Name: turtas
# City Number: 465 - City Name: beitbridge
# City Number: 466 - City Name: kanashevo
# City Number: 467 - City Name: cooma
# City Number: 468 - City Name: high rock
# City Number: 469 - City Name: pandan
# City Number: 470 - City Name: saint-francois
# City Number: 471 - City Name: longkou
# City Number: 472 - City Name: san vicente
# City Number: 473 - City Name: juneau
# City Number: 474 - City Name: oppdal
# City Number: 475 - City Name: agirish
# City Number: 476 - City Name: sayyan
# City Number: 477 - City Name: jumla
# City Number: 478 - City Name: san jose
# City Number: 479 - City Name: cache creek
# City Number: 480 - City Name: busca
# City Number: 481 - City Name: kattivakkam
# City Number: 482 - City Name: yaguajay
# City Number: 483 - City Name: vilcun
# City Number: 484 - City Name: itarema
# City Number: 485 - City Name: anchorage
# City Number: 486 - City Name: umm lajj
# City Number: 487 - City Name: brunsbuttel
# City Number: 488 - City Name: trincomalee
# City Number: 489 - City Name: san rafael
# City Number: 490 - City Name: alofi
# City Number: 491 - City Name: naze
# City Number: 492 - City Name: wanning
# City Number: 493 - City Name: ulladulla
# City Number: 494 - City Name: lakatoro
# City Number: 495 - City Name: zhanaozen
# City Number: 496 - City Name: sorong
# City Number: 497 - City Name: south lake tahoe
# City Number: 498 - City Name: kapit
# City Number: 499 - City Name: nakatsu
# City Number: 500 - City Name: maragogi
# City Number: 501 - City Name: naryan-mar
# City Number: 502 - City Name: high level
# City Number: 503 - City Name: santa rosa
# City Number: 504 - City Name: saint anthony
# City Number: 505 - City Name: kanganpur
# City Number: 506 - City Name: kupang
# City Number: 507 - City Name: boone
# City Number: 508 - City Name: takapau
# City Number: 509 - City Name: luwingu
# City Number: 510 - City Name: ellisras
# City Number: 511 - City Name: shahreza
# City Number: 512 - City Name: veraval
# City Number: 513 - City Name: janakkala
# City Number: 514 - City Name: chokurdakh
# City Number: 515 - City Name: parker
# City Number: 516 - City Name: broome
# City Number: 517 - City Name: guilford
# City Number: 518 - City Name: bambanglipuro
# City Number: 519 - City Name: oriximina
# City Number: 520 - City Name: oka
# City Number: 521 - City Name: saint-nazaire
# City Number: 522 - City Name: curuca
# City Number: 523 - City Name: ambon
# City Number: 524 - City Name: mina
# City Number: 525 - City Name: moses lake
# City Number: 526 - City Name: gimli
# City Number: 527 - City Name: campos
# City Number: 528 - City Name: maumere
# City Number: 529 - City Name: mountain home
# City Number: 530 - City Name: mitsamiouli
# City Number: 531 - City Name: kropotkin
# City Number: 532 - City Name: zhangjiakou
# City Number: 533 - City Name: fort dodge
# City Number: 534 - City Name: lixourion
# City Number: 535 - City Name: verkhniy ufaley
# City Number: 536 - City Name: hami
# City Number: 537 - City Name: marrakesh
# City Number: 538 - City Name: boshnyakovo
# City Number: 539 - City Name: hays
# City Number: 540 - City Name: udachnyy
# City Number: 541 - City Name: ballater
# City Number: 542 - City Name: biak
# City Number: 543 - City Name: erzin
# City Number: 544 - City Name: rorvik
# City Number: 545 - City Name: buin
# ---------------------------------
# There are 545 cities that DO have info
# there are 68 cities that DO NOT have any info
# ----------------------------------

# %%
ts = pd.to_datetime(datetime.now())
tempDict['Temp'].replace('',np.nan, inplace=True)

Complete_WeatherDF = tempDict.dropna(subset=['Temp'])

print(f"The original tempDict Data Frame's shape is: {tempDict.shape}")
print(f"The new DataFrame including only valid cities with temperatures shape is: {Complete_WeatherDF.shape}")
print(f"There were {noinfo} cities in the original tempDict Data Frame that did not have any info.")
Complete_WeatherDF.head()
# Out:
# The original tempDict Data Frame's shape is: (613, 10)
# The new DataFrame including only valid cities with temperatures shape is: (545, 10)
# There were 68 cities in the original tempDict Data Frame that did not have any info.
#         City        Lat         Lng   Temp Humidity Cloudiness Wind Speed  \
# 1     padang  -9.490875   87.206593  82.04       75         38       7.36
# 2    markovo  56.781816   40.225382  86.32       54          0      16.11
# 3  busselton -64.050340   86.129991  52.27       73          3      18.28
# 4        gat  23.750677   12.073141  84.20       62          0       8.05
# 5     albany -42.644933  114.881081  66.92       59          1       9.17
#
#   Country        Date    City ID
# 1      ID  1562504482  1633419.0
# 2      BG  1562504998   727921.0
# 3      AU  1562504999  2075265.0
# 4      SN  1562504999  2249901.0
# 5      US  1562504411  5106834.0

# %%
Complete_WeatherDF.to_csv('Complete_WeatherDF.csv')

tempDict.to_csv('tempDict_DF.csv')

# %%
y = Complete_WeatherDF.Temp
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o', edgecolors='black')
plt.title(f"City Latitude vs. Max Temp \n(Time: {ts})")
plt.xlabel('Latitude')
plt.ylabel('Temperature(F)')
plt.grid(True)
plt.savefig('WeatherPy_Temp.vs.Lat.png')
plt.show()

# %%
y = Complete_WeatherDF.Humidity
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o', edgecolors='black')
plt.title(f'City Latitude vs. Humidity \n(Time: {ts})')
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
### Note for ylim - I added the ylim because sometimes a city would pull back a humidity percentage that was greater than
### 100% and it would distort the visualization...
plt.ylim(0,110)
plt.grid(True)
plt.savefig('WeatherPy_Humidity.vs.Lat.png')
plt.show()

# %%
y = Complete_WeatherDF.Cloudiness
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o', edgecolors='black')
plt.title(f'City Latitude vs. Cloudiness \n(Time: {ts})')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.grid(True)
plt.savefig('WeatherPy_Cloudiness.vs.Lat.png')
plt.show()

# %%
y = Complete_WeatherDF['Wind Speed']
x = Complete_WeatherDF.Lat
plt.scatter(x,y,marker = 'o', edgecolors='black')
plt.title(f'City Latitude vs. Wind Speed \n(Time: {ts})')
plt.xlabel('Latitude')
plt.grid(True)
plt.ylabel('Wind Speed(mph)')
plt.savefig('WeatherPy_WindSpeed.vs.Lat.png')
plt.show()
